# %%
import pandas as pd

india_weather= pd.DataFrame({
    "place":["hyderaad","delhi","banglore"],
    "temperature":[40,45,50],
    "humidity":[80,70,60]
    
})
india_weather
# Out:
#       place  temperature  humidity
# 0  hyderaad           40        80
# 1     delhi           45        70
# 2  banglore           50        60

# %%
us_weather= pd.DataFrame({
    "place":["nyk","chicago","la"],
    "temperature":[60,75,50],
    "humidity":[69,71,80]
    
})
us_weather
# Out:
#      place  temperature  humidity
# 0      nyk           60        69
# 1  chicago           75        71
# 2       la           50        80

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#       place  temperature  humidity
# 0  hyderaad           40        80
# 1     delhi           45        70
# 2  banglore           50        60
# 3       nyk           60        69
# 4   chicago           75        71
# 5        la           50        80

# %%
df=pd.concat([india_weather,us_weather],keys=["india","us"])
df
# Out:
#             place  temperature  humidity
# india 0  hyderaad           40        80
#       1     delhi           45        70
#       2  banglore           50        60
# us    0       nyk           60        69
#       1   chicago           75        71
#       2        la           50        80

# %%
df.loc["india"]
# Out:
#       place  temperature  humidity
# 0  hyderaad           40        80
# 1     delhi           45        70
# 2  banglore           50        60

# %%
df.loc["us"]
# Out:
#      place  temperature  humidity
# 0      nyk           60        69
# 1  chicago           75        71
# 2       la           50        80
